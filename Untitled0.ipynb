# %%
from google.colab import files  # Import library to upload files

# Upload the CSV file from your PC
uploaded = files.upload()

# Read the uploaded data into a Pandas DataFrame
for fn in uploaded.keys():
  df = pd.read_csv(fn)
# Out:
#      <input type="file" id="files-369c1ce1-3117-4fc7-9d37-bf909394d8cb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-369c1ce1-3117-4fc7-9d37-bf909394d8cb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
# Distribution of a numerical variable
sns.distplot(df['Age'])
plt.xlabel('Age')
plt.ylabel('Monthly Income')
plt.title('Monthly Income and Age')
plt.show()

# Relationship between categorical and numerical variables
sns.boxplot(x = "latitude", y = "longitude", data=df)
plt.xlabel('latitude')
plt.ylabel('longitude')
plt.title('longitude and Latitude')
plt.show()
# Out:
# <ipython-input-13-80aea8e4e9f1>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])

# %%
import numpy as np

# Sample arrays
arr1 = np.array([12.9766, 12.9770,12.9551,12.9473,12.9850])
arr2 = np.array([77.5993, 77.5773	, 77.6593,77.5616,77.5533])

# Concatenate vertically (stacking)
concatenated_v = np.vstack([arr1, arr2])
print(concatenated_v)
# Out:
# [[12.9766 12.977  12.9551 12.9473 12.985 ]
#  [77.5993 77.5773 77.6593 77.5616 77.5533]]

# %%
total_orders = df.groupby('Age')['Family size'].sum()
print(total_orders)
# Out:
# Age
# 18      5
# 19     18
# 20     21
# 21     69
# 22    192
# 23    224
# 24    164
# 25    153
# 26    109
# 27     74
# 28     46
# 29     57
# 30     40
# 31     31
# 32     65
# 33      5
# Name: Family size, dtype: int64

# %%
std_dev = np.std(df['Age'])
print("Standard deviation of Age:", std_dev)
# Out:
# Standard deviation of Age: 2.9717556601591526

# %%
# Squared values of 'col1' (converted to NumPy array for operations)
squared_col1 = df['Age']**2
print("Squared values of Age:", squared_col1.to_numpy())
# Out:
# Squared values of Age: [ 400  576  484  484  484  729  484  576  529  529  484  529  529  441
#   529  576  784  529  625  441  576  484  484  529  441  625  484  484
#   529  484  484  484  625  484  484  625  625 1024  529  529  900  529
#   529  484  484  729  576  529  529  484  529  529  576  625  484  784
#   484  576  961  625  529  484  529  529  529  625  576  529  529  576
#   484  576  625  529  676  576  676  441  484  576  576  529  529  484
#   529  576  576  625  625  784  729  676  484  576  529  625  529  529
#   676 1024  576  529  484  576  676  784  676  625  625  324  441  625
#   625  529  529  625  961  576 1024  625  729  676  676 1024  576  729
#   529  625  529  529  784 1024  529  361  361  729  625 1089  676  484
#   529  484  625  900  576  625  529  576 1024  484  529  529  400  441
#   576  529  625 1024  729  400  441  676  625  676  676  729  729  576
#   625  400  484  676  729  625  576  529  484  676  676  625  841  529
# ...

# %%
filtered_df = df[df['Occupation'].str.contains('udent')]
print("Filtered DataFrame:", filtered_df)
# Out:
# Filtered DataFrame:      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...
